# %%
import dbutils


success_message = "CICD deployment to dev environment completed successfully."
file_path = "/dbfs/FileStore/cicd_success.txt"

dbutils.fs.put(file_path, success_message, overwrite=True)
    
print(f"Success marker written to: {file_path}")
